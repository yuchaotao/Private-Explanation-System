# %%
# %load_ext autoreload
# %autoreload 2

# %%
import run
import measure

import pickle
from scipy import stats
import numpy as np
import pandas as pd
import glob

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

#Supress default INFO logging

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

import sys
sys.path.append('../../')
sys.path.append('../')


import german.default as german_default
import german.questions as german_questions
import german.parameters as german_parameters
import german.valid as german_valid

import ipums.default as ipums_default
import ipums.valid as ipums_valid
import ipums.questions as ipums_questions
import ipums.parameters as ipums_parameters

# %%
plt.rcParams['text.usetex'] = True
sns.set(style='whitegrid', font_scale=1.2)

# %%
df = []

for default, dataset, qprefix, questions in zip(
    [ipums_default.default, german_default.default], 
    ['IPUMS', 'German'],
    ['I', 'G'],
    [ipums_valid.questions, german_valid.questions],
):
    default = {**run.DEFAULT, **default} 
    for i, question in enumerate(questions):
        controls = []
        for rho in [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 2, 5, 10]:
            controls.append(
                [
                    ('rho_rank', rho)
                ]
            )
        for gamma in np.r_[np.linspace(0.1, 0.9, 9), [0.95, 0.99]]:
            controls.append(
                [
                    ('gamma', gamma)
                ]
            )
        for setting_change in controls:
            setting = default.copy()
            for key, value in setting_change: 
                setting[key] = value
            hashed = run.hash_setting(setting)
            fprefix = f'./intermediates/{hashed}'
            widths = []
            covers = []
            for fname in glob.glob(fprefix + '*'):
                with open(fname, 'rb') as finp:
                    intermediates = pickle.load(finp)
                width = np.mean([(ci[1] - ci[0]) for ci in intermediates['RankCI']])
                widths.append(width)
            width = np.mean(widths)
            cover = np.mean([
                ci[0] <= intermediates['InfluScores'][p]['influence'] <= ci[1]
                for p, ci in zip(intermediates['Topk'], intermediates['InfluCI'])
            ])
            df.append({
                'Question': f'{qprefix}{i+1}',
                'Interval Width': width,
                'Coverage Probability': cover * 100,
                'Privacy Budget of Rank CI': setting['rho_rank'],
                'Confidence Level': setting['gamma'] 
            })
df = pd.DataFrame(df)

# %%
fig, ax = plt.subplots(figsize=(4.5,2))
sns.lineplot(data=df.query(r'`Confidence Level` == 0.95'), 
             x='Privacy Budget of Rank CI', y='Interval Width', 
             hue='Question', 
             style='Question', 
             lw = 3,
             ax = ax,
             alpha = 0.75,
             markersize = 9,
             markers=True, 
             dashes=True)
# ax.legend(ncol=2, loc=(0.12, 1.05))
ax.legend(ncol=2)
ax.set_xscale('log')
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
# ax.set_ylim(0, None)
fig.savefig(f'./plots/Rankci-budget.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(4.5,2))
sns.lineplot(data=df.query(r'`Privacy Budget of Rank CI` == 1.0'), 
             x='Confidence Level', y='Interval Width', 
             hue='Question', 
             style='Question', 
             lw = 3,
             ax = ax,
             alpha = 0.75,
             markersize = 9,
             markers=True, 
             dashes=True)
# ax.legend(ncol=2)
ax.legend(ncol=2, loc=(0.44, 0.03))
# ax.set_xscale('log')
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
# ax.set_ylim(0, None)
fig.savefig(f'./plots/Rankci-gamma.pdf', bbox_inches='tight')

# %%
df
# Out:
#    Question  Interval Width  Coverage Probability  Privacy Budget of Rank CI  \
# 0        I1          109.78                 100.0                      0.001
# 1        I1           85.24                 100.0                      0.005
# 2        I1           72.18                 100.0                      0.010
# 3        I1           17.82                 100.0                      0.050
# 4        I1            3.36                 100.0                      0.100
# 5        I1            2.16                 100.0                      0.500
# 6        I1            1.80                 100.0                      1.000
# 7        I1            1.80                 100.0                      2.000
# 8        I1            1.40                 100.0                      5.000
# 9        I1            1.16                 100.0                     10.000
# 10       I1            1.68                 100.0                      1.000
# 11       I1            1.76                 100.0                      1.000
# 12       I1            1.84                 100.0                      1.000
# 13       I1            1.84                 100.0                      1.000
# 14       I1            1.68                 100.0                      1.000
# 15       I1            1.80                 100.0                      1.000
# 16       I1            1.76                 100.0                      1.000
# 17       I1            1.76                 100.0                      1.000
# 18       I1            1.92                 100.0                      1.000
# 19       I1            1.96                 100.0                      1.000
# 20       I1            2.00                 100.0                      1.000
# 21       G1           71.44                 100.0                      0.001
# 22       G1           35.50                 100.0                      0.005
# 23       G1           15.52                 100.0                      0.010
# 24       G1            5.36                 100.0                      0.050
# 25       G1            4.70                 100.0                      0.100
# 26       G1            2.12                 100.0                      0.500
# 27       G1            1.82                 100.0                      1.000
# 28       G1            1.76                 100.0                      2.000
# 29       G1            1.14                 100.0                      5.000
# 30       G1            1.00                 100.0                     10.000
# 31       G1            1.58                 100.0                      1.000
# 32       G1            1.36                 100.0                      1.000
# 33       G1            1.56                 100.0                      1.000
# 34       G1            1.56                 100.0                      1.000
# 35       G1            1.64                 100.0                      1.000
# 36       G1            1.54                 100.0                      1.000
# 37       G1            1.58                 100.0                      1.000
# 38       G1            1.80                 100.0                      1.000
# 39       G1            1.78                 100.0                      1.000
# 40       G1            1.82                 100.0                      1.000
# 41       G1            1.94                 100.0                      1.000
#
#     Confidence Level
# 0               0.95
# 1               0.95
# 2               0.95
# 3               0.95
# 4               0.95
# 5               0.95
# 6               0.95
# 7               0.95
# 8               0.95
# 9               0.95
# 10              0.10
# 11              0.20
# 12              0.30
# 13              0.40
# 14              0.50
# 15              0.60
# 16              0.70
# 17              0.80
# 18              0.90
# 19              0.95
# 20              0.99
# 21              0.95
# 22              0.95
# 23              0.95
# 24              0.95
# 25              0.95
# 26              0.95
# 27              0.95
# 28              0.95
# 29              0.95
# 30              0.95
# 31              0.10
# 32              0.20
# 33              0.30
# 34              0.40
# 35              0.50
# 36              0.60
# 37              0.70
# 38              0.80
# 39              0.90
# 40              0.95
# 41              0.99
