# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')

import pandas as pd
import pprint

from privex.components.basic import Schema, Dataset, Predicate, GroupbyQuery, Question
from privex.components.utils import generate_explanation_predicates
from privex.framework.solution import ExplanationSession

import logging
logger = logging.getLogger(__name__)

# %%
df = pd.read_csv('../data/taxi/taxi_speed.csv')
schema = Schema.from_json('../data/taxi/taxi.json')
dataset = Dataset(df, schema)
gamma = 0.95
attributes = ['PU_Zone', 'PU_Hour', 'PU_WeekDay', 'DO_Zone', 'DO_Hour', 'DO_WeekDay']
predicates = generate_explanation_predicates(attributes, schema, strategy='1-way marginal')
es = ExplanationSession(dataset, gamma, predicates)

# %%
# Phase 1
groupby_query = GroupbyQuery(
    agg = 'AVG',
    attr_agg = 'trip_speed',
    predicate = Predicate('PU_Borough == "Manhattan"'),
    attr_group = 'PU_Zone',
    schema = schema
)
rho_query = 0.1
es.phase_1_submit_query(groupby_query, rho_query)
print(f'submiited queries with rho = {rho_query}')
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 
'display.max_colwidth', 1000):
    print(es.phase_1_show_query_results())
# Out:
# submiited queries with rho = 0.1
#                                                 group         answer
# 80                            (Central Harlem North,)   -4319.896087
# 123                     (Spuyten Duyvil/Kingsbridge,)   -3480.387191
# 35                                  (West Concourse,)   -2150.345142
# 162                          (Soundview/Castle Hill,)   -1652.713143
# 252                                  (Arden Heights,)   -1527.558107
# 150                      (Springfield Gardens North,)   -1425.793523
# 233                             (Van Cortlandt Park,)   -1394.898351
# 31                               (LaGuardia Airport,)   -1232.355116
# 83                                (Prospect Heights,)   -1109.785122
# 38                                 (Lenox Hill West,)   -1032.422344
# 111                                   (North Corona,)    -647.273940
# 250                                    (Westerleigh,)    -549.418110
# 194                                     (Mount Hope,)    -530.148910
# 17                                 (Jackson Heights,)    -518.687175
# 54                                (Brooklyn Heights,)    -487.653394
# 75                  (Long Island City/Hunters Point,)    -458.406832
# 15                                    (West Village,)    -451.489360
# 26                                (Garment District,)    -422.951639
# 30                                        (Gramercy,)    -416.026086
# 138              (East New York/Pennsylvania Avenue,)    -403.578024
# 117                                 (Manhattanville,)    -353.179932
# 221                         (Charleston/Tottenville,)    -337.459673
# 237                      (Saint George/New Brighton,)    -333.985950
# 56                                  (Sheepshead Bay,)    -333.012574
# 130                                 (Bushwick North,)    -319.813791
# 141                                (Cambria Heights,)    -301.031834
# 192                                         (Inwood,)    -299.866636
# 7                            (Upper East Side South,)    -274.125307
# 193                                     (Ozone Park,)    -271.325013
# 105                                       (Red Hook,)    -242.476855
# 177                                (Manhattan Beach,)    -223.798157
# 93                       (Williamsburg (North Side),)    -215.248665
# 131                                     (Douglaston,)    -211.102979
# 125                                  (Prospect Park,)    -204.039214
# 85                                        (Woodside,)    -180.806845
# 114                                 (Newark Airport,)    -169.006629
# 113                             (Murray Hill-Queens,)    -168.478394
# 205                                (Queensboro Hill,)    -167.780694
# 55                               (East Harlem North,)    -141.381880
# 215                  (Westchester Village/Unionport,)    -136.345717
# 190                                   (Howard Beach,)    -135.395581
# 37                                        (Kips Bay,)    -135.320911
# 166                                   (Borough Park,)    -133.965451
# 87                                  (Bushwick South,)    -123.960775
# 132                            (Crown Heights North,)    -122.052541
# 161                                      (Flatlands,)    -118.188778
# 0                            (Upper West Side South,)    -115.255562
# 109                           (Van Nest/Morris Park,)    -114.592081
# 165                                     (Pelham Bay,)    -114.017773
# 228                        (Bloomfield/Emerson Hill,)    -110.003823
# 244            (Breezy Point/Fort Tilden/Riis Beach,)    -103.851268
# 210                                  (Dyker Heights,)    -101.081822
# 223                    (Heartland Village/Todt Hill,)    -101.064609
# 218                                 (Pelham Parkway,)     -97.242125
# 108                                  (Richmond Hill,)     -97.080150
# 84                                   (Alphabet City,)     -96.432089
# 219                       (South Beach/Dongan Hills,)     -88.025961
# 203                                         (Hollis,)     -80.651355
# 44                                    (Clinton West,)     -78.524496
# 127                   (Flushing Meadows-Corona Park,)     -78.226492
# 220                                       (Rosedale,)     -75.852151
# 188                                        (Erasmus,)     -73.317857
# 19                                     (JFK Airport,)     -72.597545
# 72                                (Hamilton Heights,)     -69.673790
# 29                                     (Cobble Hill,)     -69.087002
# 13                                              (NV,)     -67.784953
# 236                (Marine Park/Floyd Bennett Field,)     -66.923427
# 77                                    (Bloomingdale,)     -66.657502
# 100                                      (Rego Park,)     -66.342411
# 222                                     (Whitestone,)     -65.355992
# 8                                     (East Chelsea,)     -64.721804
# 224                                        (Belmont,)     -63.995898
# 120                                     (Ocean Hill,)     -63.746702
# 217                                    (Marble Hill,)     -62.621858
# 119                               (South Ozone Park,)     -61.373990
# 68                                         (Seaport,)     -60.746777
# 124                                        (Madison,)     -60.334587
# 128                            (Kingsbridge Heights,)     -54.242539
# 212                                      (Homecrest,)     -47.986222
# 230                        (Arrochar/Fort Wadsworth,)     -46.411292
# 99                                             (nan,)     -46.355987
# 34                                        (Union Sq,)     -43.804721
# 144                   (East Flatbush/Remsen Village,)     -37.408502
# 147                                    (Hunts Point,)     -34.321902
# 176                                (Pelham Bay Park,)     -34.268571
# 240                                  (Port Richmond,)     -33.315895
# 6                               (World Trade Center,)     -32.266356
# 28                             (UN/Turtle Bay South,)     -29.701899
# 178                                (Highbridge Park,)     -27.404955
# 4                     (Penn Station/Madison Sq West,)     -25.915986
# 96                               (Hillcrest/Pomonok,)     -23.534166
# 226                                      (Woodhaven,)     -23.293194
# 94                                     (Fort Greene,)     -22.295871
# 11                           (Upper East Side North,)     -21.908214
# 106                                     (Greenpoint,)     -21.077993
# 202                                (Jamaica Estates,)     -18.059823
# 121                                        (Jamaica,)     -18.005377
# 81                               (East Williamsburg,)     -17.954301
# 246                      (Forest Park/Highland Park,)     -15.349344
# 134                                  (East New York,)     -13.015812
# 53                                     (Old Astoria,)     -12.229250
# 146                                       (Flushing,)     -11.883586
# 156                                   (Bedford Park,)     -11.776590
# 64                         (Queensbridge/Ravenswood,)     -11.095335
# 16                             (Morningside Heights,)     -10.511823
# 70                         (Two Bridges/Seward Park,)      -9.554686
# 198                                         (Corona,)      -9.167113
# 90                              (South Williamsburg,)      -8.773344
# 241                               (Inwood Hill Park,)      -8.234727
# 167                                  (Melrose South,)      -7.719823
# 189                                     (Bath Beach,)      -7.312757
# 216                               (Bensonhurst East,)      -6.027793
# 60                               (East Harlem South,)      -5.391965
# 239                            (Grymes Hill/Clifton,)      -2.361510
# 225                         (West Farms/Bronx River,)      -1.671295
# 46                                (Manhattan Valley,)      -0.302250
# 174                               (Sunset Park East,)       0.356036
# 257                                    (Jamaica Bay,)       0.613962
# 97                              (Stuyvesant Heights,)       0.976778
# 95                   (Long Island City/Queens Plaza,)       1.218061
# 170                                 (Queens Village,)       1.510209
# 143                                        (Maspeth,)       1.897164
# 57                               (Battery Park City,)       2.017208
# 201                                (Columbia Street,)       2.432594
# 211                            (Ocean Parkway South,)       6.208955
# 41                           (Upper West Side North,)       7.985837
# 173            (Riverdale/North Riverdale/Fieldston,)       9.506510
# 43                                            (SoHo,)      10.165886
# 59                                   (East Elmhurst,)      12.029782
# 115                                   (Forest Hills,)      13.197794
# 40                        (Financial District North,)      14.579355
# 181                                      (Bellerose,)      16.278447
# 133                                     (Highbridge,)      16.964474
# 253                                  (West Brighton,)      17.405674
# 74                                     (Boerum Hill,)      18.360075
# 42                                 (Lenox Hill East,)      18.473953
# 79                              (Soundview/Bruckner,)      19.239228
# 110                           (Flatbush/Ditmas Park,)      21.456518
# 129                      (Prospect-Lefferts Gardens,)      22.242735
# 116                                (Windsor Terrace,)      22.443157
# 157                                    (Eastchester,)      23.526066
# 22                                   (Midtown South,)      24.383881
# 256                                  (Broad Channel,)      26.436936
# 213                                     (Bronx Park,)      26.860475
# 191                             (Claremont/Bathgate,)      29.313957
# 1                                     (Midtown East,)      29.437340
# 227                                  (Willets Point,)      29.539583
# 197                                      (Gravesend,)      29.950198
# 88                                     (Kew Gardens,)      30.970910
# 65                                       (Hudson Sq,)      31.057970
# 25                       (West Chelsea/Hudson Yards,)      31.596872
# 200                                (Oakland Gardens,)      31.860140
# 10                       (Times Sq/Theatre District,)      33.003084
# 71                                     (Parkchester,)      33.468214
# 62                         (Allerton/Pelham Gardens,)      33.787260
# 159                         (Mott Haven/Port Morris,)      34.370566
# 255                                    (City Island,)      37.308416
# 92                             (Crown Heights South,)      38.695836
# 199                                        (Midwood,)      40.459732
# 63                     (Downtown Brooklyn/MetroTech,)      40.567538
# 139                                   (Far Rockaway,)      40.844493
# 66                                  (Middle Village,)      41.421229
# 36                                 (Lower East Side,)      41.786465
# 86                                         (Bedford,)      41.844330
# 3                              (Lincoln Square East,)      42.222194
# 18                                  (Midtown Center,)      42.883560
# 102                                (Carroll Gardens,)      44.211598
# 98                               (Kew Gardens Hills,)      45.948794
# 182                                       (Glendale,)      47.164416
# 122                                       (Canarsie,)      47.311138
# 229                                (Hammels/Arverne,)      47.329902
# 142                                   (Clinton Hill,)      47.574897
# 154                        (Briarwood/Jamaica Hills,)      47.773013
# 58                        (Financial District South,)      49.741929
# 47                            (TriBeCa/Civic Center,)      50.400683
# 112                                      (Bay Ridge,)      51.823458
# 14                                     (Murray Hill,)      53.824771
# 196                        (Bay Terrace/Fort Totten,)      54.742630
# 9                                     (East Village,)      58.389718
# 145                                   (Saint Albans,)      64.345793
# 149                                  (South Jamaica,)      66.298738
# 247  (Governor's Island/Ellis Island/Liberty Island,)      67.110123
# 136                             (Morrisania/Melrose,)      71.259764
# 251                            (Green-Wood Cemetery,)      77.477934
# 69                                (Sunset Park West,)      77.987254
# 33                                  (Yorkville East,)      78.896210
# 140                                        (Gowanus,)      79.173725
# 101                               (Elmhurst/Maspeth,)      81.536602
# 76                                         (Astoria,)      82.323265
# 160              (University Heights/Morris Heights,)      83.390814
# 126                                 (Brighton Beach,)      84.208669
# 238                              (Rossville/Woodrow,)      85.031466
# 245                                  (Rockaway Park,)      88.212691
# 153                       (Washington Heights North,)      88.442505
# 195                                   (Country Club,)      89.008113
# 175                                  (Fordham South,)      90.465357
# 163                                      (Bronxdale,)      97.178551
# 206                                  (Cypress Hills,)      97.358857
# 52                (East Concourse/Concourse Village,)     101.688618
# 172               (Saint Michaels Cemetery/Woodside,)     102.438252
# 104                                     (Co-Op City,)     104.460649
# 254              (Eltingville/Annadale/Prince's Bay,)     104.932168
# 151                                        (Bayside,)     106.129334
# 20                         (Greenwich Village North,)     106.776452
# 27                         (Greenwich Village South,)     107.096766
# 135                      (Springfield Gardens South,)     109.711432
# 204                          (Van Cortlandt Village,)     110.511337
# 24                                        (Flatiron,)     110.779243
# 137                         (Marine Park/Mill Basin,)     112.925119
# 158                                   (East Tremont,)     113.720920
# 232                                  (East Flushing,)     114.047488
# 185                             (Brooklyn Navy Yard,)     114.806914
# 207                                  (Fresh Meadows,)     114.809473
# 23                                        (Elmhurst,)     117.427581
# 248                                   (Crotona Park,)     121.099065
# 2                                     (Clinton East,)     121.808044
# 235                                  (College Point,)     121.954782
# 73                        (Washington Heights South,)     122.420988
# 259                                  (Rikers Island,)     123.876548
# 39                   (Meatpacking/West Village West,)     124.058836
# 187                             (Woodlawn/Wakefield,)     129.803504
# 249                                    (Great Kills,)     132.950571
# 12                   (Sutton Place/Turtle Bay North,)     134.699654
# 179                                   (Coney Island,)     142.084340
# 48                             (Lincoln Square West,)     143.221646
# 180                                     (Auburndale,)     144.392223
# 45                  (Stuy Town/Peter Cooper Village,)     144.622942
# 61                                      (Park Slope,)     147.502260
# 242                                (Mariners Harbor,)     152.688608
# 186                               (Bensonhurst West,)     154.636175
# 155                                      (Laurelton,)     156.168732
# 171                         (East Flatbush/Farragut,)     157.387750
# 164                              (Crotona Park East,)     161.926730
# 50                                    (Central Park,)     166.669767
# 91                                        (Steinway,)     173.194054
# 82                                       (Sunnyside,)     173.308337
# 234                                   (Astoria Park,)     185.261885
# 49                                    (Battery Park,)     210.240449
# 243                                      (Stapleton,)     215.092735
# 89                       (Williamsburg (South Side),)     221.676637
# 208                                       (Longwood,)     236.080840
# 78                                (Roosevelt Island,)     265.587629
# 214                   (Schuylerville/Edgewater Park,)     272.281362
# 169                       (Williamsbridge/Olinville,)     290.410281
# 118                             (DUMBO/Vinegar Hill,)     323.543191
# 32                                  (Yorkville West,)     346.021621
# 209                                      (Glen Oaks,)     361.521302
# 107                                   (Baisley Park,)     368.197392
# 168                                        (Norwood,)     387.028270
# 103                                  (Starrett City,)     433.924083
# 184                                     (Kensington,)     440.231890
# 231                                        (Oakwood,)     442.104000
# 51                                       (Chinatown,)     444.695224
# 148                                    (Brownsville,)     495.017007
# 152                                (Randalls Island,)     556.724541
# 21                             (Little Italy/NoLiTa,)     669.665702
# 258                         (New Dorp/Midland Beach,)     896.878373
# 5                                    (Midtown North,)    1023.895929
# 67                                  (Central Harlem,)    1276.080712
# 183                                      (Ridgewood,)  329408.658183

# %%
# Phase 2
def weight_mapping(group):
    if group == ('SoHo', ):
        return -1
    if group == ('Financial District North',):
        return 1
    return 0
group_weights = {
    group: weight_mapping(group)
    for group in groupby_query.groups
}
question = Question.from_group_weights(groupby_query, group_weights)
es.phase_2_submit_question(question)
es.phase_2_prepare_question_ci()
ci = es.phase_2_show_question_ci()
print('question: ', question.to_natural_language())
print(f'The {gamma*100:.0f}% confidence interval of the difference is ', ci)
# Out:
# question:  Why AVG(trip_speed) WHERE (PU_Borough == "Manhattan") and (`PU_Zone` == "Financial District North") >= AVG(trip_speed) WHERE (PU_Borough == "Manhattan") and (`PU_Zone` == "SoHo")?
# The 95% confidence interval of the difference is  (4.401676510348343, 4.426830840709455)

# %%
# Phase 3
k = 5
logger.debug(f'Length of predicates is {len(predicates)}')
rho_expl = 2.0
es.phase_3_submit_explanation_request()
es.phase_3_prepare_explanation(k, rho_expl)
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 
'display.max_colwidth', 1000, 'display.width', None, 'display.expand_frame_repr', False):
    t1, t2 = es.phase_3_show_explanation_table()
    print(t1)
    print(t2)
# Out:
# 2022-04-09 18:05:54,324 DEBUG    [<ipython-input-10-e94347c3c07d>:3] Length of predicates is 547
# 2022-04-09 18:07:09,490 DEBUG    [meta_explanation_session.py:143] 547 predicates and their influences & scores have been loaded.
# 2022-04-09 18:07:09,497 DEBUG    [meta_explanation_session.py:147]
#         influence         score
# count  547.000000    547.000000
# mean    -0.000037     -4.169963
# std      0.028455   3167.496555
# min     -0.246512 -27441.011196
# 25%      0.000000      0.000000
# 50%      0.000000      0.000000
# 75%      0.000278     30.905995
# max      0.162620  18102.379998
# 2022-04-09 18:07:09,497 DEBUG    [meta_explanation_session.py:185] total rho_expl is 2.0
# 2022-04-09 18:07:09,497 DEBUG    [meta_explanation_session.py:186] rho_topk is 0.05
# 2022-04-09 18:07:09,498 DEBUG    [meta_explanation_session.py:187] rho_ci is 0.05
# 2022-04-09 18:07:09,498 DEBUG    [meta_explanation_session.py:188] rho_rank is 1.9
# 2022-04-09 18:07:09,498 INFO     [meta_explanation_session.py:193] computing top k
# 2022-04-09 18:07:09,500 DEBUG    [meta_explanation_session.py:200] [`DO_Zone` == "JFK Airport", `PU_Zone` == "Williamsbridge/Olinville", `DO_Zone` == "Bayside", `PU_Zone` == "East Concourse/Concourse Village", `DO_Hour` == "[20, 24)"]
# 2022-04-09 18:07:09,500 INFO     [meta_explanation_session.py:203] computing influence ci
# 100%|██████████| 5/5 [00:23<00:00,  4.61s/it]
# 2022-04-09 18:07:32,570 DEBUG    [meta_explanation_session.py:214] [(0.06439433691150634, 0.13460381909394473), (-0.04341607149777124, 0.018468472513169278), (-0.04257728064275706, 0.016147274849365397), (-0.018473810318142686, 0.048265919102153616), (0.15204410473907315, 0.20593061808693097)]
# 2022-04-09 18:07:32,571 INFO     [meta_explanation_session.py:217] computing rank ci
# 100%|██████████| 5/5 [00:00<00:00, 5253.39it/s]
# 2022-04-09 18:07:32,573 DEBUG    [meta_explanation_session.py:229] [(1, 513), (1, 547), (1, 547), (1, 547), (1, 539)]
#                                         predicates Rel Inf 90-CI L Rel Inf 90-CI R  Rnk 95-CI L  Rnk 95-CI R
# 0                          `DO_Hour` == "[20, 24)"           3.45%           4.67%            1          539
# 1                       `DO_Zone` == "JFK Airport"           1.46%           3.05%            1          513
# 2  `PU_Zone` == "East Concourse/Concourse Village"          -0.42%           1.09%            1          547
# 3          `PU_Zone` == "Williamsbridge/Olinville"          -0.98%           0.42%            1          547
# 4                           `DO_Zone` == "Bayside"          -0.96%           0.37%            1          547
#                                         predicates  Inf 95-CI L  Inf 95-CI R  Rnk 95-CI L  Rnk 95-CI R
# 0                          `DO_Hour` == "[20, 24)"     0.152044     0.205931            1          539
# 1                       `DO_Zone` == "JFK Airport"     0.064394     0.134604            1          513
# 2  `PU_Zone` == "East Concourse/Concourse Village"    -0.018474     0.048266            1          547
# 3          `PU_Zone` == "Williamsbridge/Olinville"    -0.043416     0.018468            1          547
# 4                           `DO_Zone` == "Bayside"    -0.042577     0.016147            1          547

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 
'display.max_colwidth', 1000, 'display.width', None, 'display.expand_frame_repr', False):
    t1, t2 = es.phase_3_show_explanation_table()
    print(t1)
    print(t2)
# Out:
#                                predicates Rel Inf 90-CI L Rel Inf 90-CI R  Rnk 95-CI L  Rnk 95-CI R
# 0             `DO_Zone` == "Borough Park"          -0.56%           1.46%            1          547
# 1             `PU_Zone` == "Forest Hills"          -0.49%           1.23%            1          547
# 2          `DO_Zone` == "Oakland Gardens"          -1.17%           0.78%            1          547
# 3             `PU_Zone` == "West Village"          -1.39%           0.64%            1          547
# 4  `PU_Zone` == "Bloomfield/Emerson Hill"          -2.38%          -0.36%            1          547
#                                predicates  Inf 95-CI L  Inf 95-CI R  Rnk 95-CI L  Rnk 95-CI R
# 0             `DO_Zone` == "Borough Park"    -0.024636     0.064529            1          547
# 1             `PU_Zone` == "Forest Hills"    -0.021484     0.054467            1          547
# 2          `DO_Zone` == "Oakland Gardens"    -0.051708     0.034498            1          547
# 3             `PU_Zone` == "West Village"    -0.061480     0.028457            1          547
# 4  `PU_Zone` == "Bloomfield/Emerson Hill"    -0.105037    -0.015815            1          547
